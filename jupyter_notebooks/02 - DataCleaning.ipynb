# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Objectives:
# * Clean and preprocess the raw data for analysis and modeling purposes.
# * Handle missing values by imputing or removing them.
# * Handle outliers and anomalies by applying appropriate techniques.
# * Feature engineering by creating new features or transforming existing ones.
# * Save the cleaned data to a new file for further analysis and modeling.
#
# ## Inputs
# * Data file: outputs/datasets/collection/house_prices_records.csv
#
# ## Outputs
# * Cleaned data file: outputs/datasets/collection/house_prices_records_clean.csv

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
import os
pd.set_option('display.max_columns', 50)
BASE_DIR = '/workspace/Heritage-Housing-Issues'
file_path = os.path.join(BASE_DIR, 'outputs/datasets/collection/house_prices_records.csv')
df = pd.read_csv(file_path)
df.head()
# Out:
#    1stFlrSF  2ndFlrSF  BedroomAbvGr  BsmtExposure  BsmtFinSF1  BsmtFinType1  \
# 0       856     854.0           3.0           0.0         706           5.0
# 1      1262       0.0           3.0           3.0         978           4.0
# 2       920     866.0           3.0           1.0         486           5.0
# 3       961       NaN           NaN           0.0         216           4.0
# 4      1145       NaN           4.0           2.0         655           5.0
#
#    BsmtUnfSF  EnclosedPorch  GarageArea  GarageFinish  GarageYrBlt  GrLivArea  \
# 0        150            0.0         548           1.0       2003.0       1710
# 1        284            NaN         460           1.0       1976.0       1262
# 2        434            0.0         608           1.0       2001.0       1786
# 3        540            NaN         642           0.0       1998.0       1717
# 4        490            0.0         836           1.0       2000.0       2198
#
# ...
